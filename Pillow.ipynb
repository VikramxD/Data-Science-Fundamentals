# %% [markdown]
# <a href="https://colab.research.google.com/github/VikramxD/Data-Science-Fundamentals/blob/gh-pages/Pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://th.bing.com/th/id/OIP.lygNuKyE3SO_9nDG5tCYmwHaK_?w=205&h=304&c=7&o=5&dpr=1.1&pid=1.7
# Out:
# --2020-10-19 18:14:43--  https://th.bing.com/th/id/OIP.lygNuKyE3SO_9nDG5tCYmwHaK_?w=205
# Resolving th.bing.com (th.bing.com)... 204.79.197.200, 13.107.21.200, 2620:1ec:c11::200
# Connecting to th.bing.com (th.bing.com)|204.79.197.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11888 (12K) [image/jpeg]
# Saving to: ‘OIP.lygNuKyE3SO_9nDG5tCYmwHaK_?w=205’
#
# OIP.lygNuKyE3SO_9nD 100%[===================>]  11.61K  --.-KB/s    in 0s
#
# 2020-10-19 18:14:43 (65.5 MB/s) - ‘OIP.lygNuKyE3SO_9nDG5tCYmwHaK_?w=205’ saved [11888/11888]

# %%
from PIL import Image

# %%
im = Image.open('OIP.lygNuKyE3SO_9nDG5tCYmwHaK_?w=205')

# %%
array=np.array(im)

# %%
array
# Out:
# array([[[180, 186, 182],
#         [251, 255, 253],
#         [240, 246, 242],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[100, 106, 102],
#         [131, 136, 132],
#         [209, 214, 210],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[252, 255, 253],
#         [170, 175, 171],
#         [172, 177, 173],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
# ...

# %%
array.shape
# Out:
# (304, 205, 3)

# %%
plt.imshow(array)
