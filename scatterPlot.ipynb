# %% [markdown]
# <a href="https://colab.research.google.com/github/VikramxD/Data-Science-Fundamentals/blob/gh-pages/scatterPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.randn(200,2)

# %%
plt.scatter(x[:,1],x[:,0])

# %%
x[:50]=+3

# %%
Y=np.zeros(200)
Y[:50]=1

# %%
plt.scatter(x[:,0],x[:,1],c=Y)
